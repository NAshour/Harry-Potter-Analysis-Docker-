# %%
import pandas as pd

# %%
df = pd.read_csv('books.csv')
df
# Out:
#       book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 0           1            2767052       2767052   2792775          272
# 1           2                  3             3   4640799          491
# 2           3              41865         41865   3212258          226
# 3           6           11870085      11870085  16827462          226
# 4          12           13335037      13335037  13155899          210
# ...       ...                ...           ...       ...          ...
# 1349     9925              86737         86737   3877968           52
# 1350     9937           13010211      13010211  18171867           22
# 1351     9942           16074758      16074758  21869436           18
# 1352     9947           21393526      21393526  40690062           19
# 1353     9955           13065327      13065327  18230950           25
#
#             isbn        isbn13                      authors  \
# 0      439023483  9.780439e+12              Suzanne Collins
# ...

# %%
df = df.drop(['goodreads_book_id', 'best_book_id', 'work_id', 'original_title', 'language_code', 'image_url', 'small_image_url'] , axis = 1)
df
# Out:
#       book_id  books_count        isbn        isbn13  \
# 0           1          272   439023483  9.780439e+12
# 1           2          491   439554934  9.780440e+12
# 2           3          226   316015849  9.780316e+12
# 3           6          226   525478817  9.780525e+12
# 4          12          210    62024035  9.780062e+12
# ...       ...          ...         ...           ...
# 1349     9925           52  1582349177  9.781582e+12
# 1350     9937           22  1596435712  9.781596e+12
# 1351     9942           18  1442486597  9.781442e+12
# 1352     9947           19    62320521  9.780062e+12
# 1353     9955           25   802734375  9.780803e+12
#
#                           authors  original_publication_year  \
# 0                 Suzanne Collins                     2008.0
# 1     J.K. Rowling, Mary GrandPré                     1997.0
# 2                 Stephenie Meyer                     2005.0
# 3                      John Green                     2012.0
# ...

# %%
df.isna().sum()
# Out:
# book_id                       0
# books_count                   0
# isbn                         52
# isbn13                       44
# authors                       0
# original_publication_year     3
# title                         0
# average_rating                0
# ratings_count                 0
# work_ratings_count            0
# work_text_reviews_count       0
# ratings_1                     0
# ratings_2                     0
# ratings_3                     0
# ratings_4                     0
# ratings_5                     0
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
hdf = df[df['title'].str.contains("harry potter", case=False)]
hdf
# Out:
#       book_id  books_count        isbn        isbn13  \
# 1           2          491   439554934  9.780440e+12
# 6          18          376  043965548X  9.780440e+12
# 8          21          307   439358078  9.780439e+12
# 9          23          398   439064864  9.780439e+12
# 10         24          332   439139600  9.780439e+12
# 11         25          263   545010225  9.780545e+12
# 12         27          275   439785960  9.780440e+12
# 96        422           76   545044251  9.780545e+12
# 613      3753            6   439827604  9.780440e+12
# 1036     7018           42  042519891X  9.780425e+12
# 1266     9048            5  043932162X  9.780439e+12
#
#                                       authors  original_publication_year  \
# 1                 J.K. Rowling, Mary GrandPré                     1997.0
# 6     J.K. Rowling, Mary GrandPré, Rufus Beck                     1999.0
# 8                 J.K. Rowling, Mary GrandPré                     2003.0
# ...

# %%
sorted_hdf = hdf.sort_values(by='books_count', ascending=False)
best_selling = sorted_hdf.iloc[0]['title']
print(best_selling , ', number of sales:' , sorted_hdf.iloc[0]['books_count'])
# Out:
# Harry Potter and the Sorcerer's Stone (Harry Potter, #1) , number of sales: 491

# %%
avg_rating = hdf['average_rating'].sum()/len(hdf)
avg_rating
# Out:
# 4.482727272727273
